# %% [markdown]
# <a href="https://colab.research.google.com/github/Adarsh24BDA70227/flyrank-ml-track/blob/main/work/notebooks/w02_ml_task_framing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Adarsh24BDA70227/flyrank-ml-track/blob/main/work/notebooks/w02_ml_task_framing.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
## My Lane as an ML Task

#*Lane:** Content Refresh Recommendation

#*ML Task Type:** Classification

#The goal is to classify webpages into two groups: pages that are good candidates for a content refresh and pages that are not. The model helps prioritize which pages should be updated first based on historical search performance and other page features.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.


#The target is whether a webpage should be refreshed.

#ince there is no direct label saying "refresh this page," a proxy target can be created from historical data, such as pages that showed improved performance after being refreshed or pages identified by the starter dataset as refresh candidates.

#This proxy allows the model to learn useful patterns for ranking future pages.

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
#The success of the model will be measured using Precision@50.

#This metric measures how many of the top 50 recommended pages are actually good refresh candidates. A higher Precision@50 means the content team spends more time updating valuable pages and less time on low-impact pages.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Shape:", df.shape)
display(df.head())

print("\nColumns:")
print(df.columns.tolist())
# Out:
# Shape: (30000, 44)
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
#    char_count  ... char_count_tier   ctr  avg_position  engagement_rate  \
# ...

# %%
# !pwd
# Out:
# /content/flyrank-ml-track

# %%
# !ls
# Out:
# AGENTS.md  DATA_USE.md	LICENSE    README.md	     SETUP.md	 work
# CLAUDE.md  docs		notebooks  requirements.txt  skills
# data	   GUIDE.md	outputs    scripts	     submission

# %%
# !git clone https://github.com/Adarsh24BDA70227/flyrank-ml-track.git
# %cd flyrank-ml-track
# Out:
# Cloning into 'flyrank-ml-track'...
# remote: Enumerating objects: 128, done.
# remote: Counting objects: 100% (128/128), done.
# remote: Compressing objects: 100% (85/85), done.
# remote: Total 128 (delta 42), reused 92 (delta 27), pack-reused 0 (from 0)
# Receiving objects: 100% (128/128), 1.85 MiB | 14.33 MiB/s, done.
# Resolving deltas: 100% (42/42), done.
# /content/flyrank-ml-track/flyrank-ml-track

# %%
# !find . -name "*.csv"
# Out:
# ./data/raw/content_refresh_anonymized.csv
# ./outputs/refresh_queue_sample.csv

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
#A fixed rule such as refreshing every page with low clicks or low CTR ignores many other important factors.

#Machine learning considers multiple features together, including impressions, search volume, competition, content type, and engagement metrics, to identify more useful patterns.

#This allows better prioritization of webpages and provides decision support rather than relying on a single threshold.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
